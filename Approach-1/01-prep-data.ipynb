# %% [markdown]
# ## PDF and Image Text Extraction Notebook
# This notebook is designed to extract text from PDFs, including text that's embedded within images in the PDF. The steps include:
#
# Extract text and images from a given PDF.
# Use Optical Character Recognition (OCR) via Google Cloud Vision API to extract text from images.
# Write the extracted text to a JSON lines (.jsonl) file.

# %% [markdown]
# #### 1. Import Necessary Libraries

# %%
from pypdf import PdfReader as pdf_reader
from collections import defaultdict
from google.cloud import vision
from tqdm import tqdm
import logging
import json
import os

# %% [markdown]
# #### 2. Logging Setup

# %%
# Setting up logging to monitor the progress and capture any issues
logger = logging.getLogger(__name__)
logger.setLevel(logging.INFO)
logger.addHandler(logging.StreamHandler())

# %% [markdown]
# #### 3. Configure Google Cloud Credentials for Auth Process

# %%
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = './../credentials/vai-key.json'

# %% [markdown]
# #### 4. Set Local Directory Paths

# %%
# Define paths for input PDF files and output results
LOCAL_INPUT_DIR = './DATA/INPUT'
LOCAL_OUTPUT_DIR = './DATA/OUTPUT'

# %% [markdown]
# #### 5. Create Google Vision API Client

# %%
image_annotator_client = vision.ImageAnnotatorClient()

# %% [markdown]
# #### 6. Define Helper Functions
# 6.1. Extract Text and Images from PDF

# %%
def read_pdf(file_name: str) -> list:
    """
    Extracts text and images from pages of the PDF and create dictionaries with the mapped information.
    """
    text_by_page = {}
    images_by_page = defaultdict(list)
    logger.info(f'Extracting text and images from document: {file_name}')
    
    with open(f'{LOCAL_INPUT_DIR}/{file_name}.pdf', 'rb') as pdf_file:
        reader = pdf_reader(pdf_file)
        for i, page in tqdm(enumerate(reader.pages)):
            i += 1
            logger.info(f'Processing page num: {i}')
            
            # Extract text from the page
            text = page.extract_text()
            text_by_page[i] = text
            
            # Extract images from the page and save them locally
            try:
                for image in page.images:
                    IMAGE_WRITE_PATH = f'{LOCAL_OUTPUT_DIR}/{file_name}/IMAGES'
                    os.makedirs(IMAGE_WRITE_PATH, exist_ok=True)
                    images_by_page[i].extend([f'{IMAGE_WRITE_PATH}/{image.name}'])
                    with open(f'{IMAGE_WRITE_PATH}/{image.name}', 'wb') as image_file:
                        image_file.write(image.data)
            except Exception as e:
                logger.error(e)
    
    return [text_by_page, images_by_page]

# %% [markdown]
# 6.2. Extract Text from Images using OCR

# %%
def process_images_ocr(text_by_pages: dict, images_by_pages: dict) -> dict:
    for page, images in tqdm(images_by_pages.items()):  
        logger.info(f'Extracting text from images for page: {page}')
        
        # Extract text from each image using Google Vision API and append to the page's text
        for image_path in images:      
            with open(image_path, 'rb') as image_file:
                try:
                    content = image_file.read()
                    image = vision.Image(content=content)
                    response = image_annotator_client.text_detection(image=image)
                    detected_text = response.full_text_annotation.text
                    page_text = text_by_pages[page]
                    logger.info(f'Adding extracted text from image back into the page: {page}')
                    text_by_pages[page] = '\n'.join([page_text, "Text extracted from the image =>", detected_text])
                except Exception as e:
                    logger.error(e)
    
    return text_by_pages

# %% [markdown]
# 6.3. Write Extracted Text to JSON Lines File

# %%
def write_pages_to_local(file_name, text_by_pages):
    logger.info(f'Writing processed pages for {file_name} into local disk')
    JSON_WRITE_PATH = f'{LOCAL_OUTPUT_DIR}/{file_name}/TEXT'
    
    try:
        os.makedirs(JSON_WRITE_PATH, exist_ok=True)
        with open(f'{JSON_WRITE_PATH}/{file_name}.jsonl', 'w') as output_json:
            for page, text in tqdm(text_by_pages.items()):
                json_line = json.dumps({"doc_name": file_name, "page_num": page, "page_content": str(text)})
                output_json.write(json_line + '\n')
    except Exception as e:
        logger.error(e)

# %% [markdown]
# #### 7. Main Processing Function

# %%
def process_file(file_name: str):
    # Extract text and images from the PDF
    text_by_pages, images_by_pages = read_pdf(file_name)
    
    # Process the images using OCR to extract text
    text_by_pages = process_images_ocr(text_by_pages, images_by_pages)
    
    # Write the processed pages to a local directory in JSON lines format
    write_pages_to_local(file_name, text_by_pages)

# %% [markdown]
# #### 8. Execute the Process for Input Files

# %%
process_file('file-1')
process_file('file-2')
# Out:
# Extracting text and images from document: file-1
# 0it [00:00, ?it/s]Processing page num: 1
# Processing page num: 2
# 2it [00:00, 19.75it/s]Processing page num: 3
# Processing page num: 4
# Processing page num: 5
# 5it [00:00,  5.11it/s]Processing page num: 6
# Processing page num: 7
# Processing page num: 8
# Processing page num: 9
# 9it [00:01,  9.70it/s]Processing page num: 10
# Processing page num: 11
# Processing page num: 12
# 12it [00:01, 12.68it/s]Processing page num: 13
# Processing page num: 14
# Processing page num: 15
# 15it [00:01, 14.66it/s]Processing page num: 16
# Processing page num: 17
# Processing page num: 18
# 18it [00:01, 16.97it/s]Processing page num: 19
# Processing page num: 20
# Processing page num: 21
# 21it [00:01, 17.28it/s]Processing page num: 22
# Processing page num: 23
# Processing page num: 24
# 24it [00:01, 19.79it/s]Processing page num: 25
# Processing page num: 26
# Processing page num: 27
# Processing page num: 28
# 28it [00:01, 23.12it/s]Processing page num: 29
# Processing page num: 30
# Processing page num: 31
# 31it [00:01, 21.63it/s]Processing page num: 32
# 32it [00:01, 16.21it/s]
#   0%|          | 0/13 [00:00<?, ?it/s]Extracting text from images for page: 5
# Adding extracted text from image back into the page: 5
# Adding extracted text from image back into the page: 5
#   8%|▊         | 1/13 [00:00<00:06,  1.95it/s]Extracting text from images for page: 11
# Adding extracted text from image back into the page: 11
# Adding extracted text from image back into the page: 11
#  15%|█▌        | 2/13 [00:00<00:04,  2.21it/s]Extracting text from images for page: 12
# Adding extracted text from image back into the page: 12
#  23%|██▎       | 3/13 [00:01<00:04,  2.44it/s]Extracting text from images for page: 13
# Adding extracted text from image back into the page: 13
#  31%|███       | 4/13 [00:01<00:03,  2.93it/s]Extracting text from images for page: 14
# Adding extracted text from image back into the page: 14
#  38%|███▊      | 5/13 [00:01<00:02,  3.41it/s]Extracting text from images for page: 15
# Adding extracted text from image back into the page: 15
#  46%|████▌     | 6/13 [00:02<00:03,  2.26it/s]Extracting text from images for page: 16
# Adding extracted text from image back into the page: 16
# Adding extracted text from image back into the page: 16
#  54%|█████▍    | 7/13 [00:02<00:02,  2.41it/s]Extracting text from images for page: 17
# Adding extracted text from image back into the page: 17
#  62%|██████▏   | 8/13 [00:03<00:01,  2.56it/s]Extracting text from images for page: 21
# Adding extracted text from image back into the page: 21
#  69%|██████▉   | 9/13 [00:03<00:01,  2.79it/s]Extracting text from images for page: 23
# Adding extracted text from image back into the page: 23
#  77%|███████▋  | 10/13 [00:03<00:00,  3.18it/s]Extracting text from images for page: 28
# Adding extracted text from image back into the page: 28
#  85%|████████▍ | 11/13 [00:03<00:00,  3.44it/s]Extracting text from images for page: 30
# Adding extracted text from image back into the page: 30
#  92%|█████████▏| 12/13 [00:04<00:00,  3.61it/s]Extracting text from images for page: 31
# Adding extracted text from image back into the page: 31
# 100%|██████████| 13/13 [00:04<00:00,  2.92it/s]
# Writing processed pages for file-1 into local disk
# 100%|██████████| 32/32 [00:00<00:00, 12589.60it/s]
# Extracting text and images from document: file-2
# 0it [00:00, ?it/s]Processing page num: 1
# 1it [00:00,  2.27it/s]Processing page num: 2
# Processing page num: 3
# Processing page num: 4
# Processing page num: 5
# Processing page num: 6
# Processing page num: 7
# Processing page num: 8
# Processing page num: 9
# Processing page num: 10
# Processing page num: 11
# 11it [00:00, 25.77it/s]Processing page num: 12
# Processing page num: 13
# Processing page num: 14
# Processing page num: 15
# Processing page num: 16
# Processing page num: 17
# 17it [00:00, 33.79it/s]Processing page num: 18
# Processing page num: 19
# Processing page num: 20
# Processing page num: 21
# Processing page num: 22
# Processing page num: 23
# Processing page num: 24
# Processing page num: 25
# 25it [00:00, 44.57it/s]Processing page num: 26
# Processing page num: 27
# Processing page num: 28
# Processing page num: 29
# Processing page num: 30
# Processing page num: 31
# Processing page num: 32
# Processing page num: 33
# Processing page num: 34
# Processing page num: 35
# 35it [00:00, 58.57it/s]Processing page num: 36
# Processing page num: 37
# Processing page num: 38
# Processing page num: 39
# Processing page num: 40
# Processing page num: 41
# Processing page num: 42
# Processing page num: 43
# Processing page num: 44
# Processing page num: 45
# 45it [00:00, 69.13it/s]Processing page num: 46
# Processing page num: 47
# Processing page num: 48
# Processing page num: 49
# Processing page num: 50
# Processing page num: 51
# Processing page num: 52
# Processing page num: 53
# Processing page num: 54
# Processing page num: 55
# 55it [00:01, 76.80it/s]Processing page num: 56
# Processing page num: 57
# Processing page num: 58
# Processing page num: 59
# Processing page num: 60
# Processing page num: 61
# Processing page num: 62
# Processing page num: 63
# Processing page num: 64
# 64it [00:01, 63.30it/s]Processing page num: 65
# Processing page num: 66
# Processing page num: 67
# Processing page num: 68
# Processing page num: 69
# Processing page num: 70
# Processing page num: 71
# Processing page num: 72
# Processing page num: 73
# Processing page num: 74
# 74it [00:01, 71.08it/s]Processing page num: 75
# Processing page num: 76
# Processing page num: 77
# Processing page num: 78
# Processing page num: 79
# Processing page num: 80
# Processing page num: 81
# Processing page num: 82
# Processing page num: 83
# Processing page num: 84
# 84it [00:01, 78.24it/s]Processing page num: 85
# Processing page num: 86
# Processing page num: 87
# Processing page num: 88
# Processing page num: 89
# Processing page num: 90
# Processing page num: 91
# Processing page num: 92
# Processing page num: 93
# 93it [00:01, 39.20it/s]Processing page num: 94
# Processing page num: 95
# Processing page num: 96
# Processing page num: 97
# Processing page num: 98
# Processing page num: 99
# Processing page num: 100
# Processing page num: 101
# not enough image data
# Processing page num: 102
# Processing page num: 103
# 103it [00:02, 48.43it/s]Processing page num: 104
# Processing page num: 105
# Processing page num: 106
# Processing page num: 107
# Processing page num: 108
# Processing page num: 109
# Processing page num: 110
# Processing page num: 111
# Processing page num: 112
# Processing page num: 113
# 113it [00:02, 57.70it/s]Processing page num: 114
# Processing page num: 115
# Processing page num: 116
# Processing page num: 117
# Processing page num: 118
# Processing page num: 119
# Processing page num: 120
# Processing page num: 121
# Processing page num: 122
# 122it [00:02, 62.50it/s]Processing page num: 123
# Processing page num: 124
# Processing page num: 125
# Processing page num: 126
# Processing page num: 127
# Processing page num: 128
# Processing page num: 129
# Processing page num: 130
# Processing page num: 131
# 131it [00:02, 53.31it/s]Processing page num: 132
# Processing page num: 133
# Processing page num: 134
# Processing page num: 135
# Processing page num: 136
# Processing page num: 137
# Processing page num: 138
# Processing page num: 139
# Processing page num: 140
# Processing page num: 141
# Processing page num: 142
# 142it [00:02, 63.67it/s]Processing page num: 143
# Processing page num: 144
# Processing page num: 145
# Processing page num: 146
# Processing page num: 147
# Processing page num: 148
# Processing page num: 149
# Processing page num: 150
# Processing page num: 151
# Processing page num: 152
# Processing page num: 153
# Processing page num: 154
# 154it [00:02, 74.48it/s]Processing page num: 155
# Processing page num: 156
# Processing page num: 157
# Processing page num: 158
# Processing page num: 159
# Processing page num: 160
# Processing page num: 161
# Processing page num: 162
# Processing page num: 163
# 163it [00:02, 78.09it/s]Processing page num: 164
# Processing page num: 165
# Processing page num: 166
# Processing page num: 167
# Processing page num: 168
# Processing page num: 169
# Processing page num: 170
# Processing page num: 171
# Processing page num: 172
# Processing page num: 173
# Processing page num: 174
# 174it [00:02, 84.71it/s]Processing page num: 175
# Processing page num: 176
# Processing page num: 177
# Processing page num: 178
# Processing page num: 179
# Processing page num: 180
# Processing page num: 181
# Processing page num: 182
# Processing page num: 183
# Processing page num: 184
# Processing page num: 185
# 185it [00:03, 89.65it/s]Processing page num: 186
# Processing page num: 187
# Processing page num: 188
# Processing page num: 189
# Processing page num: 190
# Processing page num: 191
# Processing page num: 192
# Processing page num: 193
# Processing page num: 194
# Processing page num: 195
# 195it [00:03, 87.86it/s]Processing page num: 196
# Processing page num: 197
# Processing page num: 198
# Processing page num: 199
# Processing page num: 200
# Processing page num: 201
# Processing page num: 202
# Processing page num: 203
# Processing page num: 204
# Processing page num: 205
# Processing page num: 206
# 206it [00:03, 91.91it/s]Processing page num: 207
# Processing page num: 208
# Processing page num: 209
# Processing page num: 210
# Processing page num: 211
# Processing page num: 212
# Processing page num: 213
# Processing page num: 214
# Processing page num: 215
# Processing page num: 216
# 216it [00:03, 93.61it/s]Processing page num: 217
# Processing page num: 218
# Processing page num: 219
# Processing page num: 220
# Processing page num: 221
# Processing page num: 222
# Processing page num: 223
# Processing page num: 224
# Processing page num: 225
# Processing page num: 226
# 226it [00:03, 87.27it/s]Processing page num: 227
# Processing page num: 228
# Processing page num: 229
# Processing page num: 230
# Processing page num: 231
# Processing page num: 232
# Processing page num: 233
# Processing page num: 234
# Processing page num: 235
# 235it [00:03, 80.04it/s]Processing page num: 236
# Processing page num: 237
# Processing page num: 238
# Processing page num: 239
# Processing page num: 240
# Processing page num: 241
# Processing page num: 242
# Processing page num: 243
# Processing page num: 244
# Processing page num: 245
# Processing page num: 246
# 246it [00:03, 87.21it/s]Processing page num: 247
# Processing page num: 248
# Processing page num: 249
# Processing page num: 250
# Processing page num: 251
# Processing page num: 252
# Processing page num: 253
# Processing page num: 254
# Processing page num: 255
# Processing page num: 256
# Processing page num: 257
# Processing page num: 258
# 258it [00:03, 95.27it/s]Processing page num: 259
# Processing page num: 260
# Processing page num: 261
# Processing page num: 262
# Processing page num: 263
# Processing page num: 264
# Processing page num: 265
# Processing page num: 266
# Processing page num: 267
# Processing page num: 268
# 268it [00:03, 96.25it/s]Processing page num: 269
# Processing page num: 270
# Processing page num: 271
# Processing page num: 272
# Processing page num: 273
# Processing page num: 274
# Processing page num: 275
# Processing page num: 276
# Processing page num: 277
# Processing page num: 278
# Processing page num: 279
# 279it [00:04, 99.86it/s]Processing page num: 280
# Processing page num: 281
# Processing page num: 282
# Processing page num: 283
# Processing page num: 284
# Processing page num: 285
# Processing page num: 286
# Processing page num: 287
# Processing page num: 288
# Processing page num: 289
# Processing page num: 290
# 290it [00:04, 96.90it/s]Processing page num: 291
# Processing page num: 292
# Processing page num: 293
# Processing page num: 294
# Processing page num: 295
# Processing page num: 296
# Processing page num: 297
# Processing page num: 298
# Processing page num: 299
# Processing page num: 300
# 300it [00:04, 97.43it/s]Processing page num: 301
# Processing page num: 302
# Processing page num: 303
# Processing page num: 304
# Processing page num: 305
# Processing page num: 306
# Processing page num: 307
# Processing page num: 308
# Processing page num: 309
# Processing page num: 310
# Processing page num: 311
# Processing page num: 312
# 312it [00:04, 102.76it/s]Processing page num: 313
# Processing page num: 314
# Processing page num: 315
# Processing page num: 316
# Processing page num: 317
# Processing page num: 318
# Processing page num: 319
# Processing page num: 320
# Processing page num: 321
# Processing page num: 322
# Processing page num: 323
# 323it [00:04, 101.40it/s]Processing page num: 324
# Processing page num: 325
# Processing page num: 326
# Processing page num: 327
# Processing page num: 328
# Processing page num: 329
# Processing page num: 330
# Processing page num: 331
# Processing page num: 332
# Processing page num: 333
# Processing page num: 334
# 334it [00:04, 103.25it/s]Processing page num: 335
# Processing page num: 336
# Processing page num: 337
# Processing page num: 338
# Processing page num: 339
# Processing page num: 340
# Processing page num: 341
# Processing page num: 342
# Processing page num: 343
# Processing page num: 344
# Processing page num: 345
# Processing page num: 346
# 346it [00:04, 107.01it/s]Processing page num: 347
# Processing page num: 348
# Processing page num: 349
# Processing page num: 350
# Processing page num: 351
# Processing page num: 352
# Processing page num: 353
# Processing page num: 354
# Processing page num: 355
# Processing page num: 356
# Processing page num: 357
# Processing page num: 358
# 358it [00:04, 110.48it/s]Processing page num: 359
# Processing page num: 360
# Processing page num: 361
# Processing page num: 362
# Processing page num: 363
# Processing page num: 364
# Processing page num: 365
# Processing page num: 366
# Processing page num: 367
# Processing page num: 368
# Processing page num: 369
# Processing page num: 370
# 370it [00:04, 105.64it/s]Processing page num: 371
# Processing page num: 372
# Processing page num: 373
# Processing page num: 374
# Processing page num: 375
# Processing page num: 376
# Processing page num: 377
# Processing page num: 378
# Processing page num: 379
# Processing page num: 380
# Processing page num: 381
# Processing page num: 382
# 382it [00:05, 107.43it/s]Processing page num: 383
# Processing page num: 384
# Processing page num: 385
# Processing page num: 386
# Processing page num: 387
# Processing page num: 388
# Processing page num: 389
# Processing page num: 390
# Processing page num: 391
# Processing page num: 392
# Processing page num: 393
# 393it [00:05, 91.67it/s] Processing page num: 394
# Processing page num: 395
# Processing page num: 396
# Processing page num: 397
# Processing page num: 398
# Processing page num: 399
# Processing page num: 400
# Processing page num: 401
# Processing page num: 402
# Processing page num: 403
# 403it [00:05, 92.33it/s]Processing page num: 404
# Processing page num: 405
# Processing page num: 406
# Processing page num: 407
# Processing page num: 408
# Processing page num: 409
# Processing page num: 410
# Processing page num: 411
# Processing page num: 412
# Processing page num: 413
# 413it [00:05, 92.63it/s]Processing page num: 414
# Processing page num: 415
# Processing page num: 416
# Processing page num: 417
# Processing page num: 418
# Processing page num: 419
# Processing page num: 420
# Processing page num: 421
# Processing page num: 422
# Processing page num: 423
# Processing page num: 424
# 424it [00:05, 97.06it/s]Processing page num: 425
# Processing page num: 426
# Processing page num: 427
# Processing page num: 428
# Processing page num: 429
# Processing page num: 430
# Processing page num: 431
# Processing page num: 432
# Processing page num: 433
# Processing page num: 434
# Processing page num: 435
# 435it [00:05, 98.69it/s]Processing page num: 436
# Processing page num: 437
# Processing page num: 438
# Processing page num: 439
# Processing page num: 440
# Processing page num: 441
# Processing page num: 442
# Processing page num: 443
# Processing page num: 444
# Processing page num: 445
# Processing page num: 446
# Processing page num: 447
# 447it [00:05, 104.56it/s]Processing page num: 448
# Processing page num: 449
# Processing page num: 450
# Processing page num: 451
# Processing page num: 452
# Processing page num: 453
# Processing page num: 454
# Processing page num: 455
# Processing page num: 456
# Processing page num: 457
# Processing page num: 458
# 458it [00:05, 94.25it/s] Processing page num: 459
# Processing page num: 460
# Processing page num: 461
# Processing page num: 462
# Processing page num: 463
# Processing page num: 464
# Processing page num: 465
# Processing page num: 466
# Processing page num: 467
# Processing page num: 468
# 468it [00:05, 92.60it/s]Processing page num: 469
# Processing page num: 470
# Processing page num: 471
# Processing page num: 472
# Processing page num: 473
# Processing page num: 474
# Processing page num: 475
# Processing page num: 476
# Processing page num: 477
# Processing page num: 478
# Processing page num: 479
# Processing page num: 480
# Processing page num: 481
# 481it [00:06, 99.89it/s]Processing page num: 482
# Processing page num: 483
# Processing page num: 484
# Processing page num: 485
# Processing page num: 486
# Processing page num: 487
# Processing page num: 488
# Processing page num: 489
# Processing page num: 490
# Processing page num: 491
# Processing page num: 492
# 492it [00:06, 95.73it/s]Processing page num: 493
# Processing page num: 494
# Processing page num: 495
# Processing page num: 496
# Processing page num: 497
# Processing page num: 498
# Processing page num: 499
# Processing page num: 500
# Processing page num: 501
# Processing page num: 502
# 502it [00:06, 93.35it/s]Processing page num: 503
# Processing page num: 504
# Processing page num: 505
# Processing page num: 506
# Processing page num: 507
# Processing page num: 508
# Processing page num: 509
# Processing page num: 510
# Processing page num: 511
# Processing page num: 512
# Processing page num: 513
# 513it [00:06, 95.92it/s]Processing page num: 514
# Processing page num: 515
# Processing page num: 516
# Processing page num: 517
# Processing page num: 518
# Processing page num: 519
# Processing page num: 520
# Processing page num: 521
# Processing page num: 522
# Processing page num: 523
# Processing page num: 524
# Processing page num: 525
# 525it [00:06, 100.28it/s]Processing page num: 526
# Processing page num: 527
# Processing page num: 528
# Processing page num: 529
# Processing page num: 530
# Processing page num: 531
# Processing page num: 532
# Processing page num: 533
# Processing page num: 534
# Processing page num: 535
# Processing page num: 536
# 536it [00:06, 100.66it/s]Processing page num: 537
# Processing page num: 538
# Processing page num: 539
# Processing page num: 540
# Processing page num: 541
# Processing page num: 542
# Processing page num: 543
# Processing page num: 544
# Processing page num: 545
# Processing page num: 546
# Processing page num: 547
# 547it [00:06, 100.69it/s]Processing page num: 548
# Processing page num: 549
# Processing page num: 550
# Processing page num: 551
# Processing page num: 552
# Processing page num: 553
# Processing page num: 554
# Processing page num: 555
# Processing page num: 556
# Processing page num: 557
# Processing page num: 558
# 558it [00:06, 100.37it/s]Processing page num: 559
# Processing page num: 560
# Processing page num: 561
# Processing page num: 562
# Processing page num: 563
# Processing page num: 564
# Processing page num: 565
# Processing page num: 566
# Processing page num: 567
# Processing page num: 568
# Processing page num: 569
# Processing page num: 570
# Processing page num: 571
# 571it [00:06, 107.67it/s]Processing page num: 572
# Processing page num: 573
# Processing page num: 574
# Processing page num: 575
# Processing page num: 576
# Processing page num: 577
# Processing page num: 578
# Processing page num: 579
# Processing page num: 580
# Processing page num: 581
# Processing page num: 582
# 582it [00:07, 101.77it/s]Processing page num: 583
# Processing page num: 584
# Processing page num: 585
# Processing page num: 586
# Processing page num: 587
# Processing page num: 588
# Processing page num: 589
# Processing page num: 590
# Processing page num: 591
# Processing page num: 592
# Processing page num: 593
# 593it [00:07, 99.70it/s] Processing page num: 594
# Processing page num: 595
# Processing page num: 596
# Processing page num: 597
# Processing page num: 598
# Processing page num: 599
# Processing page num: 600
# Processing page num: 601
# Processing page num: 602
# Processing page num: 603
# Processing page num: 604
# 604it [00:07, 96.67it/s]Processing page num: 605
# Processing page num: 606
# Processing page num: 607
# Processing page num: 608
# Processing page num: 609
# Processing page num: 610
# Processing page num: 611
# Processing page num: 612
# Processing page num: 613
# Processing page num: 614
# 614it [00:07, 77.81it/s]Processing page num: 615
# Processing page num: 616
# Processing page num: 617
# Processing page num: 618
# Processing page num: 619
# Processing page num: 620
# Processing page num: 621
# Processing page num: 622
# Processing page num: 623
# Processing page num: 624
# 624it [00:07, 82.82it/s]Processing page num: 625
# Processing page num: 626
# Processing page num: 627
# Processing page num: 628
# Processing page num: 629
# Processing page num: 630
# Processing page num: 631
# Processing page num: 632
# Processing page num: 633
# Processing page num: 634
# Processing page num: 635
# 635it [00:07, 79.80it/s]Processing page num: 636
# Processing page num: 637
# Processing page num: 638
# Processing page num: 639
# Processing page num: 640
# Processing page num: 641
# Processing page num: 642
# Processing page num: 643
# Processing page num: 644
# 644it [00:07, 78.58it/s]Processing page num: 645
# Processing page num: 646
# Processing page num: 647
# Processing page num: 648
# Processing page num: 649
# Processing page num: 650
# Processing page num: 651
# Processing page num: 652
# Processing page num: 653
# Processing page num: 654
# Processing page num: 655
# Processing page num: 656
# 656it [00:08, 88.09it/s]Processing page num: 657
# Processing page num: 658
# Processing page num: 659
# Processing page num: 660
# Processing page num: 661
# Processing page num: 662
# Processing page num: 663
# Processing page num: 664
# Processing page num: 665
# Processing page num: 666
# 666it [00:08, 90.99it/s]Processing page num: 667
# Processing page num: 668
# Processing page num: 669
# Processing page num: 670
# Processing page num: 671
# Processing page num: 672
# Processing page num: 673
# Processing page num: 674
# Processing page num: 675
# Processing page num: 676
# 676it [00:08, 89.32it/s]Processing page num: 677
# Processing page num: 678
# Processing page num: 679
# Processing page num: 680
# Processing page num: 681
# Processing page num: 682
# Processing page num: 683
# Processing page num: 684
# Processing page num: 685
# Processing page num: 686
# 686it [00:08, 81.95it/s]Processing page num: 687
# Processing page num: 688
# Processing page num: 689
# Processing page num: 690
# Processing page num: 691
# Processing page num: 692
# Processing page num: 693
# Processing page num: 694
# Processing page num: 695
# 695it [00:08, 73.84it/s]Processing page num: 696
# Processing page num: 697
# Processing page num: 698
# Processing page num: 699
# Processing page num: 700
# Processing page num: 701
# Processing page num: 702
# Processing page num: 703
# Processing page num: 704
# Processing page num: 705
# Processing page num: 706
# Processing page num: 707
# Processing page num: 708
# Processing page num: 709
# 709it [00:08, 88.11it/s]Processing page num: 710
# Processing page num: 711
# Processing page num: 712
# Processing page num: 713
# Processing page num: 714
# Processing page num: 715
# Processing page num: 716
# Processing page num: 717
# Processing page num: 718
# Processing page num: 719
# Processing page num: 720
# Processing page num: 721
# Processing page num: 722
# 722it [00:08, 97.94it/s]Processing page num: 723
# Processing page num: 724
# Processing page num: 725
# Processing page num: 726
# Processing page num: 727
# Processing page num: 728
# Processing page num: 729
# Processing page num: 730
# Processing page num: 731
# Processing page num: 732
# Processing page num: 733
# 733it [00:08, 96.09it/s]Processing page num: 734
# Processing page num: 735
# Processing page num: 736
# Processing page num: 737
# Processing page num: 738
# Processing page num: 739
# Processing page num: 740
# Processing page num: 741
# Processing page num: 742
# Processing page num: 743
# Processing page num: 744
# Processing page num: 745
# 745it [00:08, 101.42it/s]Processing page num: 746
# Processing page num: 747
# Processing page num: 748
# Processing page num: 749
# Processing page num: 750
# Processing page num: 751
# Processing page num: 752
# Processing page num: 753
# Processing page num: 754
# Processing page num: 755
# Processing page num: 756
# 756it [00:09, 92.82it/s] Processing page num: 757
# Processing page num: 758
# Processing page num: 759
# Processing page num: 760
# Processing page num: 761
# Processing page num: 762
# Processing page num: 763
# Processing page num: 764
# Processing page num: 765
# Processing page num: 766
# 766it [00:09, 86.56it/s]Processing page num: 767
# Processing page num: 768
# Processing page num: 769
# Processing page num: 770
# Processing page num: 771
# Processing page num: 772
# Processing page num: 773
# Processing page num: 774
# Processing page num: 775
# Processing page num: 776
# Processing page num: 777
# 777it [00:09, 90.09it/s]Processing page num: 778
# Processing page num: 779
# Processing page num: 780
# Processing page num: 781
# Processing page num: 782
# Processing page num: 783
# Processing page num: 784
# Processing page num: 785
# Processing page num: 786
# Processing page num: 787
# 787it [00:09, 79.30it/s]Processing page num: 788
# Processing page num: 789
# Processing page num: 790
# Processing page num: 791
# Processing page num: 792
# Processing page num: 793
# Processing page num: 794
# Processing page num: 795
# Processing page num: 796
# 796it [00:09, 78.54it/s]Processing page num: 797
# Processing page num: 798
# Processing page num: 799
# Processing page num: 800
# Processing page num: 801
# Processing page num: 802
# Processing page num: 803
# Processing page num: 804
# Processing page num: 805
# 805it [00:09, 72.87it/s]Processing page num: 806
# Processing page num: 807
# Processing page num: 808
# Processing page num: 809
# Processing page num: 810
# Processing page num: 811
# Processing page num: 812
# Processing page num: 813
# Processing page num: 814
# Processing page num: 815
# 815it [00:09, 77.41it/s]Processing page num: 816
# Processing page num: 817
# Processing page num: 818
# Processing page num: 819
# Processing page num: 820
# Processing page num: 821
# Processing page num: 822
# Processing page num: 823
# 823it [00:10, 77.52it/s]Processing page num: 824
# Processing page num: 825
# Processing page num: 826
# Processing page num: 827
# Processing page num: 828
# Processing page num: 829
# Processing page num: 830
# Processing page num: 831
# Processing page num: 832
# 832it [00:10, 79.12it/s]Processing page num: 833
# Processing page num: 834
# Processing page num: 835
# Processing page num: 836
# Processing page num: 837
# Processing page num: 838
# Processing page num: 839
# Processing page num: 840
# Processing page num: 841
# 841it [00:10, 80.95it/s]Processing page num: 842
# Processing page num: 843
# Processing page num: 844
# Processing page num: 845
# Processing page num: 846
# Processing page num: 847
# Processing page num: 848
# Processing page num: 849
# Processing page num: 850
# 850it [00:10, 80.36it/s]Processing page num: 851
# Processing page num: 852
# Processing page num: 853
# Processing page num: 854
# Processing page num: 855
# Processing page num: 856
# Processing page num: 857
# Processing page num: 858
# Processing page num: 859
# Processing page num: 860
# Processing page num: 861
# 861it [00:10, 87.02it/s]Processing page num: 862
# Processing page num: 863
# Processing page num: 864
# Processing page num: 865
# Processing page num: 866
# Processing page num: 867
# Processing page num: 868
# Processing page num: 869
# Processing page num: 870
# 870it [00:10, 84.38it/s]Processing page num: 871
# Processing page num: 872
# Processing page num: 873
# Processing page num: 874
# Processing page num: 875
# Processing page num: 876
# Processing page num: 877
# Processing page num: 878
# Processing page num: 879
# 879it [00:10, 85.80it/s]Processing page num: 880
# Processing page num: 881
# Processing page num: 882
# Processing page num: 883
# Processing page num: 884
# Processing page num: 885
# Processing page num: 886
# Processing page num: 887
# Processing page num: 888
# 888it [00:10, 82.35it/s]Processing page num: 889
# Processing page num: 890
# Processing page num: 891
# Processing page num: 892
# Processing page num: 893
# Processing page num: 894
# Processing page num: 895
# Processing page num: 896
# Processing page num: 897
# 897it [00:10, 76.36it/s]Processing page num: 898
# Processing page num: 899
# Processing page num: 900
# Processing page num: 901
# Processing page num: 902
# Processing page num: 903
# Processing page num: 904
# Processing page num: 905
# Processing page num: 906
# Processing page num: 907
# Processing page num: 908
# Processing page num: 909
# 909it [00:11, 86.45it/s]Processing page num: 910
# Processing page num: 911
# Processing page num: 912
# Processing page num: 913
# Processing page num: 914
# Processing page num: 915
# Processing page num: 916
# Processing page num: 917
# Processing page num: 918
# Processing page num: 919
# Processing page num: 920
# 920it [00:11, 92.58it/s]Processing page num: 921
# Processing page num: 922
# Processing page num: 923
# Processing page num: 924
# Processing page num: 925
# Processing page num: 926
# Processing page num: 927
# Processing page num: 928
# Processing page num: 929
# Processing page num: 930
# Processing page num: 931
# Processing page num: 932
# 932it [00:11, 98.87it/s]Processing page num: 933
# Processing page num: 934
# Processing page num: 935
# Processing page num: 936
# Processing page num: 937
# Processing page num: 938
# Processing page num: 939
# Processing page num: 940
# Processing page num: 941
# Processing page num: 942
# Processing page num: 943
# Processing page num: 944
# 944it [00:11, 103.08it/s]Processing page num: 945
# Processing page num: 946
# Processing page num: 947
# Processing page num: 948
# Processing page num: 949
# Processing page num: 950
# Processing page num: 951
# Processing page num: 952
# Processing page num: 953
# Processing page num: 954
# Processing page num: 955
# Processing page num: 956
# Processing page num: 957
# 957it [00:11, 109.02it/s]Processing page num: 958
# Processing page num: 959
# Processing page num: 960
# Processing page num: 961
# Processing page num: 962
# Processing page num: 963
# Processing page num: 964
# Processing page num: 965
# Processing page num: 966
# Processing page num: 967
# Processing page num: 968
# 968it [00:11, 108.43it/s]Processing page num: 969
# Processing page num: 970
# Processing page num: 971
# Processing page num: 972
# Processing page num: 973
# Processing page num: 974
# Processing page num: 975
# Processing page num: 976
# Processing page num: 977
# Processing page num: 978
# Processing page num: 979
# Processing page num: 980
# 980it [00:11, 110.55it/s]Processing page num: 981
# Processing page num: 982
# Processing page num: 983
# Processing page num: 984
# Processing page num: 985
# Processing page num: 986
# Processing page num: 987
# Processing page num: 988
# Processing page num: 989
# Processing page num: 990
# Processing page num: 991
# Processing page num: 992
# 992it [00:11, 105.78it/s]Processing page num: 993
# Processing page num: 994
# Processing page num: 995
# Processing page num: 996
# Processing page num: 997
# Processing page num: 998
# Processing page num: 999
# Processing page num: 1000
# Processing page num: 1001
# Processing page num: 1002
# Processing page num: 1003
# 1003it [00:11, 100.54it/s]Processing page num: 1004
# Processing page num: 1005
# Processing page num: 1006
# Processing page num: 1007
# Processing page num: 1008
# Processing page num: 1009
# Processing page num: 1010
# Processing page num: 1011
# Processing page num: 1012
# Processing page num: 1013
# Processing page num: 1014
# 1014it [00:11, 103.04it/s]Processing page num: 1015
# Processing page num: 1016
# Processing page num: 1017
# Processing page num: 1018
# Processing page num: 1019
# Processing page num: 1020
# Processing page num: 1021
# Processing page num: 1022
# Processing page num: 1023
# Processing page num: 1024
# Processing page num: 1025
# 1025it [00:12, 77.51it/s] Processing page num: 1026
# Processing page num: 1027
# Processing page num: 1028
# Processing page num: 1029
# Processing page num: 1030
# Processing page num: 1031
# Processing page num: 1032
# Processing page num: 1033
# Processing page num: 1034
# 1034it [00:12, 73.82it/s]Processing page num: 1035
# Processing page num: 1036
# Processing page num: 1037
# Processing page num: 1038
# Processing page num: 1039
# Processing page num: 1040
# Processing page num: 1041
# Processing page num: 1042
# Processing page num: 1043
# 1043it [00:12, 71.74it/s]Processing page num: 1044
# Processing page num: 1045
# Processing page num: 1046
# Processing page num: 1047
# Processing page num: 1048
# Processing page num: 1049
# Processing page num: 1050
# Processing page num: 1051
# 1051it [00:12, 71.51it/s]Processing page num: 1052
# Processing page num: 1053
# Processing page num: 1054
# Processing page num: 1055
# Processing page num: 1056
# Processing page num: 1057
# Processing page num: 1058
# Processing page num: 1059
# 1059it [00:12, 61.63it/s]Processing page num: 1060
# Processing page num: 1061
# Processing page num: 1062
# Processing page num: 1063
# Processing page num: 1064
# Processing page num: 1065
# Processing page num: 1066
# 1066it [00:12, 62.87it/s]Processing page num: 1067
# Processing page num: 1068
# Processing page num: 1069
# Processing page num: 1070
# Processing page num: 1071
# Processing page num: 1072
# Processing page num: 1073
# Processing page num: 1074
# 1074it [00:12, 66.89it/s]Processing page num: 1075
# Processing page num: 1076
# Processing page num: 1077
# Processing page num: 1078
# Processing page num: 1079
# Processing page num: 1080
# Processing page num: 1081
# Processing page num: 1082
# 1082it [00:13, 60.60it/s]Processing page num: 1083
# Processing page num: 1084
# Processing page num: 1085
# Processing page num: 1086
# Processing page num: 1087
# Processing page num: 1088
# Processing page num: 1089
# 1089it [00:13, 81.92it/s]
#   0%|          | 0/7 [00:00<?, ?it/s]Extracting text from images for page: 61
# Adding extracted text from image back into the page: 61
# Adding extracted text from image back into the page: 61
#  14%|█▍        | 1/7 [00:00<00:02,  2.27it/s]Extracting text from images for page: 85
# Adding extracted text from image back into the page: 85
#  29%|██▊       | 2/7 [00:01<00:05,  1.10s/it]Extracting text from images for page: 127
# Adding extracted text from image back into the page: 127
#  43%|████▎     | 3/7 [00:02<00:02,  1.38it/s]Extracting text from images for page: 225
# Adding extracted text from image back into the page: 225
#  57%|█████▋    | 4/7 [00:02<00:01,  1.87it/s]Extracting text from images for page: 228
# Adding extracted text from image back into the page: 228
#  71%|███████▏  | 5/7 [00:02<00:00,  2.18it/s]Extracting text from images for page: 316
# Adding extracted text from image back into the page: 316
#  86%|████████▌ | 6/7 [00:03<00:00,  2.58it/s]Extracting text from images for page: 605
# Adding extracted text from image back into the page: 605
# 100%|██████████| 7/7 [00:03<00:00,  2.05it/s]
# Writing processed pages for file-2 into local disk
# 100%|██████████| 1089/1089 [00:00<00:00, 54468.88it/s]
